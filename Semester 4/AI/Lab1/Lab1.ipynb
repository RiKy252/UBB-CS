# %%
aValues1 = [1,2,3,4]

print(aValues1[2]) # rank 1

aValues2 = [[1,2],[3,4],[5,6]]

print(aValues2[1]) #axis 1
print(aValues2[1][1]) # rank 2
# Out:
# 3
# [3, 4]
# 4

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)
y2 = np.cos(x)

# Create a 1x2 grid of plots
plt.subplot(1, 2, 1)  # 1 row, 2 columns, first plot
plt.plot(x, y, label="sin(x)")
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()

plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
plt.plot(x, y2, label="cos(x)", color='r')
plt.title("Cosine Wave")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.legend()

plt.tight_layout()  # Adjust spacing between plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [30, 25, 20, 25]  # Percentages
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']  # Custom colors
explode = (0.1, 0, 0, 0)  # Explode the first slice (Category A)

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    sizes,
    labels=labels,
    colors=colors,
    explode=explode,
    autopct='%1.1f%%',  # Show percentages with 1 decimal place
    startangle=90,      # Rotate the start of the pie chart
    shadow=True         # Add a shadow effect
)

plt.title("Pie Chart Example")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(44)

t = np.arange(0, 30, 0.01)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10 Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, NFFT=256, Fs=1. / 0.01)
axs[1].set_ylabel('Coherence')

plt.show()

# %%
import torch
a = torch.tensor([1, 2, 3, 4])  # 1D tensor
b = torch.tensor([[1, 2], [3, 4]])  # 2D tensor
a,b
# Out:
# (tensor([1, 2, 3, 4]),
#  tensor([[1, 2],
#          [3, 4]]))

# %%
from PIL import Image
# Correct file path
image_path = r'C:\Users\bolog\Pictures\Screenshots\asd.png'  # Option 1: Use a raw string

# Load the image
image = Image.open(image_path)

# Summarize some details about the image
print("Format:", image.format)
print("Mode:", image.mode)
print("Size:", image.size)

# Show the image
image.show()
# Out:
# Format: PNG
# Mode: RGBA
# Size: (1919, 1079)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 20
#      18 from matplotlib import pyplot
#      19 # load image as pixel array
# ---> 20 data = image.imread('asd.png')
#      21 # summarize shape of the pixel array
#      22 print(data.dtype)
#
# File d:\Tools\Anaconda\Lib\site-packages\matplotlib\image.py:1544, in imread(fname, format)
#    1537 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1538     # Pillow doesn't handle URLs directly.
#    1539     raise ValueError(
#    1540         "Please open the URL for reading and pass the "
#    1541         "result to Pillow, e.g. with "
#    1542         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1543         )
# -> 1544 with img_open(fname) as image:
#    1545     return (_pil_png_to_float_array(image)
#    1546             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1547             pil_to_array(image))
#
# File d:\Tools\Anaconda\Lib\site-packages\PIL\ImageFile.py:126, in ImageFile.__init__(self, fp, filename)
#     122 self.decodermaxblock = MAXBLOCK
#     124 if is_path(fp):
#     125     # filename
# --> 126     self.fp = open(fp, "rb")
#     127     self.filename = fp
#     128     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'asd.png'

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread(r'C:\Users\bolog\Pictures\Screenshots\asd.png')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# float32
# (1079, 1919, 4)

# %%
# create a thumbnail of an image
from PIL import Image
# load the image
image = Image.open(r'C:\Users\bolog\Pictures\Screenshots\asd.png')
# report the size of the image
print(image.size)
# create a thumbnail and preserve aspect ratio
image.thumbnail((100,100))
# report the size of the thumbnail
print(image.size)
# Out:
# (1919, 1079)
# (100, 56)
